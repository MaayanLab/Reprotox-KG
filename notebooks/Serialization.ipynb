# %%
import json
import rdflib
import re
import pandas as pd
from rdflib import URIRef, BNode, Literal, Graph, RDF, Namespace, ODRL2, RDFS
import requests
import time
from tqdm import tqdm
import urllib.parse
from maayanlab_bioinformatics.utils import fetch_save_read, merge
from functools import lru_cache
import glob

# %%
@lru_cache()
def ncbi_genes_fetch(organism='Mammalia/Homo_sapiens', filters=lambda ncbi: (ncbi['type_of_gene'] == "protein-coding")):
    ''' Fetch the current NCBI Human Gene Info database.
    See ftp://ftp.ncbi.nih.gov/gene/DATA/GENE_INFO/ for the directory/file of the organism of interest.
    '''
    def maybe_split(record):
        ''' NCBI Stores Nulls as '-' and lists '|' delimited
        '''
        if record in {'', '-'}:
            return set()
        return set(record.split('|'))
    #
    def supplement_dbXref_prefix_omitted(ids):
        ''' NCBI Stores external IDS with Foreign:ID while most datasets just use the ID
        '''
        for id in ids:
          # add original id
          yield id
          # also add id *without* prefix
          if ':' in id:
            yield id.split(':', maxsplit=1)[1]
    #
    ncbi = fetch_save_read(
    'ftp://ftp.ncbi.nih.gov/gene/DATA/GENE_INFO/{}.gene_info.gz'.format(organism),
    '{}.gene_info.tsv'.format(organism),
    sep='\t',
    )
    if filters and callable(filters):
        ncbi = ncbi[filters(ncbi)]
    #
    ncbi['All_synonyms'] = [
        set.union(
          maybe_split(gene_info['Symbol']),
          maybe_split(gene_info['Symbol'].upper()),
          maybe_split(gene_info['Symbol_from_nomenclature_authority']),
          maybe_split(str(gene_info['GeneID'])),
          maybe_split(gene_info['Synonyms']),
          maybe_split(gene_info['Other_designations']),
          maybe_split(gene_info['LocusTag']),
          set(supplement_dbXref_prefix_omitted(maybe_split(gene_info['dbXrefs']))),
        )
        for _, gene_info in ncbi.iterrows()
    ]
    return ncbi

@lru_cache()                  
def ncbi_genes_lookup(organism='Mammalia/Homo_sapiens', filters=lambda ncbi: ncbi['type_of_gene']=='protein-coding'):
    ''' Return a lookup dictionary with synonyms as the keys, and official symbols as the values
    Usage:
    ```python
    ncbi_lookup = ncbi_genes_lookup('Mammalia/Homo_sapiens')
    print(ncbi_lookup('STAT3')) # any alias will get converted into the official symbol
    ```
    '''
    ncbi_genes = ncbi_genes_fetch(organism=organism)
    synonyms, symbols, gene_ids = zip(*{
    (synonym, gene_info['Symbol'], gene_info['GeneID'])
    for _, gene_info in ncbi_genes.iterrows()
    for synonym in gene_info['All_synonyms']
    })
    ncbi_lookup = pd.Series(symbols, index=synonyms)
    index_values = ncbi_lookup.index.value_counts()
    ncbi_lookup_disambiguated = ncbi_lookup.drop(index_values[index_values > 1].index)
    for i in symbols:
        if i not in ncbi_lookup_disambiguated.index:
            ncbi_lookup_disambiguated[i] = i
    
    ncbi_lookup_id = pd.Series(gene_ids, index=synonyms)
    index_values_id = ncbi_lookup_id.index.value_counts()
    ncbi_lookup_disambiguated_id = ncbi_lookup_id.drop(index_values_id[index_values_id > 1].index)
    ncbi_genes = ncbi_genes.set_index("GeneID")
    for i in gene_ids:
        gene = ncbi_genes.at[i, "Symbol"]
        if gene not in ncbi_lookup_disambiguated_id.index:
            ncbi_lookup_disambiguated_id[gene] = i

    return ncbi_lookup_disambiguated.to_dict().get, ncbi_lookup_disambiguated_id.get

symbol_mapper, gene_id_mapper = ncbi_genes_lookup()
def get_info(gene):
    return(symbol_mapper(gene), str(gene_id_mapper(gene)))

get_info('NOS1'), get_info('HAUS1P1')
# Out:
# (('NOS1', '4842'), (None, 'None'))

# %%
get_info('KCNQ1OT1')
# Out:
# (None, 'None')

# %%
gene_scores = pd.read_csv("https://raw.githubusercontent.com/nih-cfde/ReproToxTables/main/Susceptibility%20Scores%20and%20GWAS%20Gene%20Lists/Susceptibility%20Scores/All%20Scores.csv", index_col=0)
gene_scores.head()
# Out:
#                       pLI  Residual.Variation.Intolerance.Score  \
# Gene Symbol
# A1BG         9.064924e-05                             -0.466531
# A1CF         3.619701e-03                             -0.378346
# A2M          5.401149e-04                              0.099179
# A2ML1        1.329022e-22                              2.419901
# A4GALT       1.115987e-01                             -0.290161
#
#              Residual.Variation.Intolerance.Score.Percentile      pHI      pTS
# Gene Symbol
# A1BG                                               23.513800  0.13450  0.52075
# A1CF                                               28.013682  0.21197  0.22586
# A2M                                                60.757254  0.92010  0.39196
# A2ML1                                              98.525596  0.27137  0.18193
# A4GALT                                             33.339231  0.14511  0.09411

# %%
drug_scores = pd.read_csv("data/L1000_2021_Signature_Similarity_predicted_drug_table.csv", index_col=0)
drug_scores["Rank"] = drug_scores.Similarity_Score.rank(method="first")
drug_scores.head()
# Out:
#                Similarity_Score     Rank
# FTI-276                0.111335  33473.0
# BRD-K08703257          0.104131  33472.0
# temozolomide           0.102109  33471.0
# Gossypetin             0.101613  33470.0
# TAK-715                0.100779  33469.0

# %%
HPO_Freq = pd.read_csv("data/HPO_Freq.tsv", sep="\t", index_col=1)
HPO_Freq.head()
# Out:
#                                    HPO description  KF Frequency
# HPO ID
# HP:0410030                               Cleft lip           888
# HP:0000776         Congenital diaphragmatic hernia           770
# HP:0000175                            Cleft palate           704
# HP:0010438  Abnormal ventricular septum morphology           629
# HP:0001710                      Conotruncal defect           545

# %%
associations = {
  'https://raw.githubusercontent.com/nih-cfde/ReproToxTables/main/CDC-birth-defects/Geneshot_BirthDefects_Gene_Associations.ttl': "Geneshot",
  'https://raw.githubusercontent.com/nih-cfde/ReproToxTables/main/CDC-birth-defects/Drugshot_BirthDefects_Drug_Associations.ttl': "Drugshot",
  'https://raw.githubusercontent.com/nih-cfde/ReproToxTables/main/CDC-birth-defects/DrugEnrichr_BirthDefects_Drug_Associations.ttl': "DrugEnrichr",
}

# %%
with open("data/birth_defects.json") as o:
    birth_defects = json.loads(o.read())

with open("data/drug_ref.json") as o:
    drugs = json.loads(o.read())
    for k,v in drugs.items():
        new_dict = {}
        for i,j in v.items():
            new_dict[i.replace(".", "_")] = j
        drugs[k] = new_dict

with open("data/gene_ref.json") as o:
    genes = json.loads(o.read())
    for k,v in genes.items():
        new_dict = {}
        for i,j in v.items():
            new_dict[i.replace(".", "_")] = j
        genes[k] = new_dict

# %%
for k,v in genes.items():
    a = v.pop("Residual.Variation.Intolerance.Score", None)
    if a:
        v["Residual_Variation_Intolerance_Score"] = a
    a = v.pop("Residual.Variation.Intolerance.Score.Percentile", None)
    if a:
        v["Residual_Variation_Intolerance_Score_Percentile"] = a

# %%
from cProfile import label


drug_ids = {
    "LY-294002": "CID:3973",
    "PD-98059": "CID:4713"
}

birth_defect_ids = {}

iri_mappers = [
  dict(
    cls='BirthDefect',
    expr=re.compile(r'^https://www\.orpha\.net/ORDO/(?P<id>.+)$'),
  ),
  dict(
    cls='BirthDefect',
    expr=re.compile(r'^https://purl\.obolibrary\.org/obo/(?P<id>.+)$'),
  ),
  dict(
    cls='Gene',
    expr=re.compile(r'^https://identifiers\.org/hgnc\.symbol/(?P<symbol>.+)$'),
  ),
  dict(
    cls='Drug',
    expr=re.compile(r'^https://identifiers\.org/lincs\.smallmolecule:(?P<id>.+)$'),
  ),
  # dict(
  #   cls='Relationship',
  #   expr=re.compile(r'^https://semanticscience\.org/resource/(?P<id>.+)$'),
  # ),
  dict(
    cls='BirthDefect',
    expr=re.compile(r'^https://hpo\.jax\.org/app/browse/term/(?P<id>.+)$'),
  ),
]

relationships = {
  "SIO_010299": "disease",
  "SIO_010056": "phenotype",
  "SIO_000993": "chemical-disease",
  "SIO_000983": "gene-disease"
}

orpha = {}
def iri_to_node(iri):
    for mapper in iri_mappers:
        iri = iri.replace("HP_", "HP:")
        m = mapper['expr'].match(iri)
        if m:
            group_dict = m.groupdict()
            if mapper['cls'] == "Gene":
              gene_label, gene_id = get_info(genes[group_dict["symbol"]]["label"])
              if gene_label == "ND1":
                print(gene_id)
              if gene_label:
                properties = {
                  "id": gene_id,
                  "label": gene_label
                }
                if gene_label in gene_scores:
                  print(gene_label)
                  for k,v in gene_scores.loc[group_dict["symbol"]]:
                    properties[k.replace(".", "_" )] = v
                properties["uri"] = "https://www.ncbi.nlm.nih.gov/gene/%s"%gene_id
              else:
                print(genes[group_dict["symbol"]])
                properties = genes[group_dict["symbol"]]
                properties["uri"] = "https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=%s"%group_dict["symbol"]
              return { "type": mapper['cls'], "properties": {**properties}}
            elif mapper['cls'] == "Drug":
              gd = {**drugs[group_dict["id"]]}
              if not str(drugs[group_dict["id"]]["id"]).startswith("LSM"):
                old_uid = "CID:%s"%(drugs[group_dict["id"]]["id"])   
                uid = old_uid
                label = drugs[group_dict["id"]]["label"]
                if label not in drug_ids:
                  drug_ids[label] = uid
                else: uid = drug_ids[label]
                gd["id"] = uid
                gd["uri"] = "https://pubchem.ncbi.nlm.nih.gov/compound/%s"%str(old_uid)
              return {"type": mapper['cls'], "properties": gd}
            elif mapper['cls'] == "BirthDefect":
              birth_defect_id = group_dict["id"]
              if birth_defect_id in birth_defects:
                birth_defect = birth_defects[birth_defect_id]
                if birth_defect not in birth_defect_ids:
                    birth_defect_ids[birth_defect] = birth_defect_id
                else: 
                    birth_defect_id = birth_defect_ids[birth_defect]
                properties = {
                  "id": birth_defect_id,
                  "label": birth_defect,
                  "uri": "https://purl.obolibrary.org/obo/=%s"%birth_defect
                }
                return { "type": mapper['cls'], "properties": {**properties}}
              elif birth_defect_id in orpha:
                properties = orpha[birth_defect_id]
                birth_defect = properties["label"]
                birth_defect_id = properties["id"]
                if birth_defect not in birth_defect_ids:
                    birth_defect_ids[birth_defect] = birth_defect_id
                else: 
                    birth_defect_id = birth_defect_ids[birth_defect]
                properties["id"] = birth_defect_id
                return { "type": mapper['cls'], "properties": {**properties}}
              else:
                res = requests.get("https://www.ebi.ac.uk/ols/api/select?q=%s"%birth_defect_id)
                if not res.ok:
                  print("ERROR %s"%birth_defect_id)
                  print(res.text)
                else:
                  print(birth_defect_id)
                  birth_defect = res.json()["response"]["docs"][0]["label"]
                  birth_defect_id = res.json()["response"]["docs"][0]["obo_id"]
                  if birth_defect not in birth_defect_ids:
                      birth_defect_ids[birth_defect] = birth_defect_id
                  else: 
                      birth_defect_id = birth_defect_ids[birth_defect]
                  
                  properties = {
                    "id": birth_defect_id,
                    "label": birth_defect,
                    "uri": res.json()["response"]["docs"][0]["iri"]
                  }
                  orpha[birth_defect_id.replace(":", "_")] = properties
                  return { "type": mapper['cls'], "properties": {**properties}}
            # else:
            #   # print(group_dict)

              
              
            # if "id" in group_dict:
            #     if group_dict["id"] in birth_defects:
            #         group_dict["label"] = birth_defects[group_dict["id"]]
            #         return {"type": mapper['cls'], "properties": group_dict}
            #     elif group_dict["id"] in drugs:
            #         gd = drugs[group_dict["id"]]
            #         if mapper['cls'] == 'Drug':
            #           gd["id"] = "CID:%s"%str(drugs[group_dict["id"]]["id"])
            #         return {"type": mapper['cls'], "properties": gd}
            #     elif group_dict["id"] in relationships:
            #         group_dict["label"] = relationships[group_dict["id"]]
            #         return {"type": mapper['cls'], "properties": group_dict}
            # elif "symbol" in group_dict:
            #     gene_symbol, gene_id = get_info(group_dict["symbol"])
            #     if gene_symbol and gene_id:
            #       properties = genes[group_dict["symbol"]]
            #       properties["label"] = gene_symbol
            #       properties["id"] = gene_id
            #       properties["uri"] = "https://www.ncbi.nlm.nih.gov/gene/%s"%gene_id
            #       return { "type": mapper['cls'], "properties": {**group_dict, **properties}}
            #     else:
            #       return { "type": mapper['cls'], "properties": {**group_dict, 
            #         **genes[group_dict["symbol"]],
            #         "uri": "https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=%s"%group_dict["symbol"]
            #       }}
            # return {"type": mapper['cls'], "properties": group_dict}

# %%
edges = []
nodes = {}
hpo_ids = set()
no_freq = set()
new_ids = {}
drug_uids = set()
for assoc, resource in associations.items():
    rdfgraph = rdflib.Graph()
    rdfgraph.parse(assoc, format='ttl')
    for i in rdfgraph.all_nodes():
        iri = iri_to_node(i)
        if iri and str(iri["properties"]["id"]) not in nodes:
            if iri["type"] == "Drug":
                # iri["properties"]["uri"] = "https://pubchem.ncbi.nlm.nih.gov/compound/%s"%str(iri["properties"]["id"].replace("CID:", ""))
                uid = str(iri["properties"]["id"])           
                nodes[uid] = {
                    **iri,
                }
            elif iri["type"] == "Gene":
                uid = str(iri["properties"]["id"])
                label = iri["properties"]["label"]
                iri["properties"]["id"] = uid
                nodes[uid] = {
                    **iri,  
                }
            elif iri["type"] == "BirthDefect" and str(iri["properties"]["id"].startswith("HP:")):
                # iri["properties"]["uri"] = "https://purl.obolibrary.org/obo/=%s"%str(iri["properties"]["id"])
                node_id = str(iri["properties"]["id"])
                label = iri["properties"]["label"]
                
                iri["properties"]["id"] = node_id
                nodes[node_id] = {
                    **iri,
                }
                if node_id in HPO_Freq.index:
                    nodes[node_id]["KF_freq"] = int(HPO_Freq.at[str(iri["properties"]["id"]), 'KF Frequency'])
                    hpo_ids.add(node_id)
                else:
                    no_freq.add(node_id)
            else:
                uid = str(iri["properties"]["id"])
                label = iri["properties"]["label"]
                iri["properties"]["id"] = uid
                nodes[str(iri["properties"]["id"])] = {
                    **iri,
                    "uri": str(i)
                }
    for subj, pred, obj in rdfgraph.triples((None, None, None)):
        subj_iri = iri_to_node(subj)
        obj_iri = iri_to_node(obj)
        if subj_iri and nodes[str(subj_iri["properties"]["id"])] and obj_iri and nodes[str(obj_iri["properties"]["id"])]:
            pred = str(pred)
            n = iri_to_node(pred)
            if n and n["id"]:
                pred = relationships[n["id"]]
            
            edges.append({
                "type": "Relation",
                "source": str(subj_iri["properties"]["id"]),
                "relation": "%s"%resource,#(resource, relationships[pred.split("/")[-1]]),
                "target": str(obj_iri["properties"]["id"]),
                "properties": {
                    "id": "%s_%s_%s"%(subj_iri["properties"]["label"], relationships[pred.split("/")[-1]], obj_iri["properties"]["label"]),
                    "source_label": subj_iri["properties"]["label"],
                    "target_label": obj_iri["properties"]["label"],
                    "directed": True,
                    "resource": resource
                }
            })
# Out:
# {'id': 'ENSG00000269821', 'label': 'KCNQ1OT1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=KCNQ1OT1'}
# {'id': 'ENSG00000283785', 'label': 'MIR15A', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR15A'}
# {'id': 'ENSG00000283609', 'label': 'MIR4662A', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4662A'}
# {'id': 'ENSG00000283634', 'label': 'MIR3155B', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR3155B'}
# {'id': 'ENSP00000478319', 'label': 'ENSP00000478319', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000478319'}
# {'id': 'BX546450.1', 'label': 'BX546450.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=BX546450.1'}
# {'id': 'AP002852.1', 'label': 'AP002852.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AP002852.1'}
# {'id': 'ENSP00000387760', 'label': 'ENSP00000387760', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000387760'}
# {'id': 'ENSG00000199990', 'label': 'VTRNA1-1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=VTRNA1-1'}
# {'id': 'AL157895.1', 'label': 'AL157895.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AL157895.1'}
# {'id': 'ENSG00000176840', 'label': 'MIR7-3HG', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR7-3HG'}
# {'id': 'ENSG00000239314', 'label': 'MORC1-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MORC1-AS1'}
# {'id': 'ENSG00000265539', 'label': 'MIR3164', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR3164'}
# {'id': 'ENSG00000266589', 'label': 'MIR4512', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4512'}
# {'id': 'AC116345.3', 'label': 'AC116345.3', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC116345.3'}
# {'id': 'ENSG00000266507', 'label': 'MIR4479', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4479'}
# {'id': 'ENSG00000259158', 'label': 'ADAM20P1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ADAM20P1'}
# {'id': 'ENSP00000370256', 'label': 'ENSP00000370256', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000370256'}
# {'id': 'AC093614.1', 'label': 'AC093614.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC093614.1'}
# {'id': 'ENSP00000485452', 'label': 'ENSP00000485452', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000485452'}
# {'id': 'AC124248.1', 'label': 'AC124248.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC124248.1'}
# {'id': 'ENSG00000238184', 'label': 'CD81-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=CD81-AS1'}
# {'id': 'ENSG00000188388', 'label': 'GOLGA6L3', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=GOLGA6L3'}
# {'id': 'ENSG00000189366', 'label': 'ALG1L', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ALG1L'}
# {'id': 'ENSG00000235033', 'label': 'DAAM2-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=DAAM2-AS1'}
# {'id': 'ENSG00000278851', 'label': 'MIR6879', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6879'}
# Orphanet_870
# {'id': 'ENSG00000244578', 'label': 'LINC01391', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01391'}
# {'id': 'AC126323.2', 'label': 'AC126323.2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC126323.2'}
# {'id': 'ENSG00000265507', 'label': 'MIR4435-1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4435-1'}
# {'id': 'ENSG00000260551', 'label': 'PWRN2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=PWRN2'}
# {'id': 'ENSG00000233496', 'label': 'SYNJ2-IT1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=SYNJ2-IT1'}
# {'id': 'ENSG00000186715', 'label': 'MST1L', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MST1L'}
# {'id': 'AC008132.1', 'label': 'AC008132.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC008132.1'}
# {'id': 'ENSG00000215417', 'label': 'MIR17HG', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR17HG'}
# {'id': 'ENSG00000276622', 'label': 'MIR6499', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6499'}
# {'id': 'ENSP00000245323', 'label': 'ENSP00000245323', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000245323'}
# {'id': 'ENSG00000265841', 'label': 'MIR548X', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR548X'}
# Orphanet_3378
# {'id': 'ENSG00000235191', 'label': 'NUCB1-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=NUCB1-AS1'}
# {'id': 'AC138747.5', 'label': 'AC138747.5', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC138747.5'}
# {'id': 'ENSG00000249346', 'label': 'LINC01016', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01016'}
# {'id': 'ENSG00000284202', 'label': 'MIR137', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR137'}
# {'id': 'ENSG00000205861', 'label': 'PCOTH', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=PCOTH'}
# {'id': 'AL136524.1', 'label': 'AL136524.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AL136524.1'}
# {'id': 'AC093627.27', 'label': 'AC093627.27', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC093627.27'}
# Orphanet_3380
# {'id': 'ENSP00000352561', 'label': 'ENSP00000352561', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000352561'}
# {'id': 'ENSG00000176236', 'label': 'RPP38-DT', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=RPP38-DT'}
# {'id': 'AC090061.1', 'label': 'AC090061.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC090061.1'}
# {'id': 'ENSG00000225791', 'label': 'TRAM2-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=TRAM2-AS1'}
# {'id': 'ENSG00000283935', 'label': 'MIR423', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR423'}
# {'id': 'ENSG00000242686', 'label': 'PDE6B-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=PDE6B-AS1'}
# {'id': 'ENSP00000293780', 'label': 'ENSP00000293780', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000293780'}
# {'id': 'ENSP00000480893', 'label': 'ENSP00000480893', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000480893'}
# {'id': 'ENSP00000359612', 'label': 'ENSP00000359612', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000359612'}
# {'id': 'ENSG00000235885', 'label': 'LINC01828', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01828'}
# {'id': 'AL512631.2', 'label': 'AL512631.2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AL512631.2'}
# {'id': 'ENSG00000258057', 'label': 'BCDIN3D-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=BCDIN3D-AS1'}
# {'id': 'AC104123.1', 'label': 'AC104123.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC104123.1'}
# {'id': 'AC104134.1', 'label': 'AC104134.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC104134.1'}
# {'id': 'ENSG00000255036', 'label': 'SUGT1P4-STRA6LP-CCDC180', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=SUGT1P4-STRA6LP-CCDC180'}
# {'id': 'ENSG00000237125', 'label': 'HAND2-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=HAND2-AS1'}
# {'id': 'ENSG00000281828', 'label': 'HERC2P7', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=HERC2P7'}
# {'id': 'AL354863.1', 'label': 'AL354863.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AL354863.1'}
# {'id': 'ENSG00000199077', 'label': 'MIR129-2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR129-2'}
# {'id': 'ENSG00000255568', 'label': 'BRWD1-AS2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=BRWD1-AS2'}
# {'id': 'ENSP00000295641', 'label': 'ENSP00000295641', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000295641'}
# {'id': 'ENSG00000207649', 'label': 'MIR138-2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR138-2'}
# {'id': 'C20orf197', 'label': 'C20orf197', 'pLI': 0.0552321459200376, 'Residual_Variation_Intolerance_Score': 0.103030230903726, 'Residual_Variation_Intolerance_Score_Percentile': 61.2762443972635, 'pHI': 0.16931, 'pTS': 0.03477, 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=C20orf197'}
# {'id': 'ENSG00000232652', 'label': 'LINC02829', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC02829'}
# {'id': 'ENSG00000226210', 'label': 'WASH8P', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=WASH8P'}
# {'id': 'ENSG00000284499', 'label': 'MIR363', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR363'}
# {'id': 'ENSP00000304169', 'label': 'ENSP00000304169', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000304169'}
# {'id': 'ENSG00000273874', 'label': 'MIR6859-2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6859-2'}
# {'id': 'ENSG00000207827', 'label': 'MIR30A', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR30A'}
# 4535
# {'id': 'ENSP00000319279', 'label': 'ENSP00000319279', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000319279'}
# {'id': 'HSA-MIR-377-3P', 'label': 'HSA-MIR-377-3P', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=HSA-MIR-377-3P'}
# {'id': 'ENSG00000229630', 'label': 'LINC01264', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01264'}
# {'id': 'ENSG00000262001', 'label': 'DLGAP1-AS2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=DLGAP1-AS2'}
# {'id': 'ENSG00000205611', 'label': 'LINC01597', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01597'}
# {'id': 'ENSG00000232225', 'label': 'LINC01047', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01047'}
# {'id': 'ENSG00000226864', 'label': 'ATE1-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ATE1-AS1'}
# {'id': 'ENSG00000257495', 'label': 'KRT73-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=KRT73-AS1'}
# {'id': 'AC011379.2', 'label': 'AC011379.2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC011379.2'}
# {'id': 'ENSP00000451207', 'label': 'ENSP00000451207', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000451207'}
# {'id': 'ENSG00000284087', 'label': 'MIR6844', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6844'}
# {'id': 'ENSG00000284419', 'label': 'MIR663A', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR663A'}
# {'id': 'ENSG00000208006', 'label': 'MIR16-1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR16-1'}
# {'id': 'ENSG00000198984', 'label': 'MIR345', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR345'}
# {'id': 'DGCR9', 'label': 'DGCR9', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=DGCR9'}
# {'id': 'HSA-MIR-1257', 'label': 'HSA-MIR-1257', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=HSA-MIR-1257'}
# {'id': 'ENSG00000269416', 'label': 'LINC01224', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01224'}
# {'id': 'FO681492.1', 'label': 'FO681492.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=FO681492.1'}
# {'id': 'ENSG00000106133', 'label': 'NSUN5P2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=NSUN5P2'}
# {'id': 'AC126468.1', 'label': 'AC126468.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC126468.1'}
# {'id': 'ENSG00000202560', 'label': 'MIR539', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR539'}
# {'id': 'ENSG00000258861', 'label': 'MIR381HG', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR381HG'}
# {'id': 'ENSP00000451411', 'label': 'ENSP00000451411', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000451411'}
# {'id': 'ENSG00000280109', 'label': 'PLAC4', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=PLAC4'}
# {'id': 'ENSG00000204148', 'label': 'LINC00474', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC00474'}
# {'id': 'ENSG00000206552', 'label': 'KRBOX1-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=KRBOX1-AS1'}
# {'id': 'ENSG00000274585', 'label': 'RNU2-1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=RNU2-1'}
# {'id': 'ENSG00000198974', 'label': 'MIR30E', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR30E'}
# {'id': 'ENSG00000266750', 'label': 'MIR4645', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4645'}
# {'id': 'ENSG00000250490', 'label': 'FLJ33360', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=FLJ33360'}
# {'id': 'ENSG00000225942', 'label': 'LINC01875', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01875'}
# {'id': 'AL136419.1', 'label': 'AL136419.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AL136419.1'}
# {'id': 'TNKS2-AS1', 'label': 'TNKS2-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=TNKS2-AS1'}
# {'id': 'ENSG00000274258', 'label': 'MIR6728', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6728'}
# {'id': 'ENSG00000265924', 'label': 'MIR5692C1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR5692C1'}
# {'id': 'ENSG00000237728', 'label': 'CAMTA1-AS2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=CAMTA1-AS2'}
# {'id': 'ENSG00000179994', 'label': 'SPDYE7P', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=SPDYE7P'}
# {'id': 'ENSG00000284346', 'label': 'MIR940', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR940'}
# {'id': 'ENSG00000204148', 'label': 'LINC00474', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC00474'}
# {'id': 'FO681492.1', 'label': 'FO681492.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=FO681492.1'}
# {'id': 'ENSG00000283935', 'label': 'MIR423', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR423'}
# {'id': 'ENSG00000257495', 'label': 'KRT73-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=KRT73-AS1'}
# {'id': 'C20orf197', 'label': 'C20orf197', 'pLI': 0.0552321459200376, 'Residual_Variation_Intolerance_Score': 0.103030230903726, 'Residual_Variation_Intolerance_Score_Percentile': 61.2762443972635, 'pHI': 0.16931, 'pTS': 0.03477, 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=C20orf197'}
# {'id': 'ENSG00000106133', 'label': 'NSUN5P2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=NSUN5P2'}
# {'id': 'ENSG00000284202', 'label': 'MIR137', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR137'}
# {'id': 'ENSG00000237125', 'label': 'HAND2-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=HAND2-AS1'}
# {'id': 'ENSG00000283634', 'label': 'MIR3155B', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR3155B'}
# {'id': 'ENSG00000205611', 'label': 'LINC01597', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01597'}
# {'id': 'ENSG00000273874', 'label': 'MIR6859-2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6859-2'}
# {'id': 'ENSG00000202560', 'label': 'MIR539', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR539'}
# {'id': 'ENSP00000370256', 'label': 'ENSP00000370256', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000370256'}
# {'id': 'ENSG00000265539', 'label': 'MIR3164', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR3164'}
# {'id': 'ENSG00000273874', 'label': 'MIR6859-2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6859-2'}
# {'id': 'AP002852.1', 'label': 'AP002852.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AP002852.1'}
# {'id': 'ENSP00000319279', 'label': 'ENSP00000319279', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000319279'}
# {'id': 'ENSP00000485452', 'label': 'ENSP00000485452', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000485452'}
# {'id': 'ENSG00000265507', 'label': 'MIR4435-1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4435-1'}
# {'id': 'ENSG00000244578', 'label': 'LINC01391', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01391'}
# {'id': 'ENSG00000238184', 'label': 'CD81-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=CD81-AS1'}
# {'id': 'ENSG00000265841', 'label': 'MIR548X', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR548X'}
# {'id': 'ENSG00000199990', 'label': 'VTRNA1-1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=VTRNA1-1'}
# {'id': 'ENSG00000265507', 'label': 'MIR4435-1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4435-1'}
# {'id': 'ENSG00000266750', 'label': 'MIR4645', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4645'}
# {'id': 'BX546450.1', 'label': 'BX546450.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=BX546450.1'}
# {'id': 'AC126323.2', 'label': 'AC126323.2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC126323.2'}
# {'id': 'AC090061.1', 'label': 'AC090061.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC090061.1'}
# {'id': 'AL136524.1', 'label': 'AL136524.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AL136524.1'}
# {'id': 'ENSG00000274585', 'label': 'RNU2-1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=RNU2-1'}
# {'id': 'ENSP00000352561', 'label': 'ENSP00000352561', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000352561'}
# {'id': 'ENSG00000179994', 'label': 'SPDYE7P', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=SPDYE7P'}
# {'id': 'ENSG00000281828', 'label': 'HERC2P7', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=HERC2P7'}
# {'id': 'ENSP00000451207', 'label': 'ENSP00000451207', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000451207'}
# {'id': 'ENSG00000207649', 'label': 'MIR138-2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR138-2'}
# {'id': 'ENSG00000278851', 'label': 'MIR6879', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6879'}
# {'id': 'ENSP00000451411', 'label': 'ENSP00000451411', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000451411'}
# {'id': 'ENSG00000269416', 'label': 'LINC01224', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01224'}
# {'id': 'ENSG00000239314', 'label': 'MORC1-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MORC1-AS1'}
# {'id': 'ENSG00000226864', 'label': 'ATE1-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ATE1-AS1'}
# {'id': 'ENSG00000176840', 'label': 'MIR7-3HG', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR7-3HG'}
# {'id': 'ENSG00000225791', 'label': 'TRAM2-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=TRAM2-AS1'}
# {'id': 'ENSG00000250490', 'label': 'FLJ33360', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=FLJ33360'}
# {'id': 'AC093614.1', 'label': 'AC093614.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC093614.1'}
# {'id': 'ENSP00000387760', 'label': 'ENSP00000387760', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000387760'}
# {'id': 'ENSG00000226210', 'label': 'WASH8P', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=WASH8P'}
# {'id': 'ENSG00000237728', 'label': 'CAMTA1-AS2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=CAMTA1-AS2'}
# {'id': 'ENSG00000198974', 'label': 'MIR30E', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR30E'}
# {'id': 'ENSG00000258057', 'label': 'BCDIN3D-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=BCDIN3D-AS1'}
# {'id': 'AL157895.1', 'label': 'AL157895.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AL157895.1'}
# {'id': 'ENSG00000106133', 'label': 'NSUN5P2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=NSUN5P2'}
# {'id': 'AC126323.2', 'label': 'AC126323.2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC126323.2'}
# {'id': 'ENSG00000208006', 'label': 'MIR16-1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR16-1'}
# {'id': 'ENSG00000265924', 'label': 'MIR5692C1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR5692C1'}
# {'id': 'ENSG00000232652', 'label': 'LINC02829', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC02829'}
# {'id': 'ENSG00000269821', 'label': 'KCNQ1OT1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=KCNQ1OT1'}
# {'id': 'ENSG00000215417', 'label': 'MIR17HG', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR17HG'}
# {'id': 'ENSG00000255036', 'label': 'SUGT1P4-STRA6LP-CCDC180', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=SUGT1P4-STRA6LP-CCDC180'}
# {'id': 'AC126468.1', 'label': 'AC126468.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC126468.1'}
# {'id': 'ENSG00000284087', 'label': 'MIR6844', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6844'}
# {'id': 'HSA-MIR-1257', 'label': 'HSA-MIR-1257', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=HSA-MIR-1257'}
# {'id': 'ENSG00000284419', 'label': 'MIR663A', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR663A'}
# {'id': 'AC138747.5', 'label': 'AC138747.5', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC138747.5'}
# {'id': 'AL354863.1', 'label': 'AL354863.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AL354863.1'}
# {'id': 'ENSG00000255568', 'label': 'BRWD1-AS2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=BRWD1-AS2'}
# {'id': 'ENSG00000176236', 'label': 'RPP38-DT', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=RPP38-DT'}
# {'id': 'ENSG00000202560', 'label': 'MIR539', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR539'}
# {'id': 'AC116345.3', 'label': 'AC116345.3', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC116345.3'}
# {'id': 'ENSG00000206552', 'label': 'KRBOX1-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=KRBOX1-AS1'}
# {'id': 'ENSP00000480893', 'label': 'ENSP00000480893', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000480893'}
# {'id': 'ENSG00000276622', 'label': 'MIR6499', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6499'}
# {'id': 'ENSG00000204148', 'label': 'LINC00474', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC00474'}
# {'id': 'ENSG00000199077', 'label': 'MIR129-2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR129-2'}
# {'id': 'DGCR9', 'label': 'DGCR9', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=DGCR9'}
# {'id': 'ENSG00000205861', 'label': 'PCOTH', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=PCOTH'}
# {'id': 'ENSG00000255568', 'label': 'BRWD1-AS2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=BRWD1-AS2'}
# {'id': 'ENSG00000235033', 'label': 'DAAM2-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=DAAM2-AS1'}
# {'id': 'ENSG00000235191', 'label': 'NUCB1-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=NUCB1-AS1'}
# {'id': 'HSA-MIR-377-3P', 'label': 'HSA-MIR-377-3P', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=HSA-MIR-377-3P'}
# {'id': 'AC104123.1', 'label': 'AC104123.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC104123.1'}
# {'id': 'ENSG00000205611', 'label': 'LINC01597', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01597'}
# {'id': 'ENSG00000202560', 'label': 'MIR539', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR539'}
# {'id': 'ENSG00000242686', 'label': 'PDE6B-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=PDE6B-AS1'}
# {'id': 'ENSP00000245323', 'label': 'ENSP00000245323', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000245323'}
# {'id': 'ENSG00000284346', 'label': 'MIR940', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR940'}
# {'id': 'ENSG00000235885', 'label': 'LINC01828', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01828'}
# {'id': 'ENSG00000207827', 'label': 'MIR30A', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR30A'}
# {'id': 'ENSG00000265507', 'label': 'MIR4435-1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4435-1'}
# {'id': 'ENSG00000262001', 'label': 'DLGAP1-AS2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=DLGAP1-AS2'}
# {'id': 'ENSG00000238184', 'label': 'CD81-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=CD81-AS1'}
# {'id': 'ENSG00000225942', 'label': 'LINC01875', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01875'}
# {'id': 'ENSG00000266507', 'label': 'MIR4479', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4479'}
# {'id': 'ENSG00000266589', 'label': 'MIR4512', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4512'}
# {'id': 'ENSP00000359612', 'label': 'ENSP00000359612', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000359612'}
# {'id': 'ENSG00000283785', 'label': 'MIR15A', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR15A'}
# {'id': 'AC008132.1', 'label': 'AC008132.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC008132.1'}
# {'id': 'ENSG00000274258', 'label': 'MIR6728', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6728'}
# {'id': 'AC104134.1', 'label': 'AC104134.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC104134.1'}
# {'id': 'ENSP00000295641', 'label': 'ENSP00000295641', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000295641'}
# {'id': 'ENSG00000188388', 'label': 'GOLGA6L3', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=GOLGA6L3'}
# {'id': 'AC093627.27', 'label': 'AC093627.27', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC093627.27'}
# {'id': 'ENSG00000284499', 'label': 'MIR363', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR363'}
# {'id': 'AC011379.2', 'label': 'AC011379.2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC011379.2'}
# {'id': 'ENSG00000259158', 'label': 'ADAM20P1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ADAM20P1'}
# {'id': 'AC126323.2', 'label': 'AC126323.2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC126323.2'}
# {'id': 'AC093614.1', 'label': 'AC093614.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC093614.1'}
# {'id': 'ENSG00000205861', 'label': 'PCOTH', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=PCOTH'}
# {'id': 'ENSP00000478319', 'label': 'ENSP00000478319', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000478319'}
# 4535
# {'id': 'ENSG00000229630', 'label': 'LINC01264', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01264'}
# {'id': 'ENSP00000304169', 'label': 'ENSP00000304169', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000304169'}
# {'id': 'ENSG00000235191', 'label': 'NUCB1-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=NUCB1-AS1'}
# {'id': 'ENSG00000266589', 'label': 'MIR4512', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4512'}
# {'id': 'ENSG00000269821', 'label': 'KCNQ1OT1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=KCNQ1OT1'}
# {'id': 'ENSG00000283634', 'label': 'MIR3155B', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR3155B'}
# {'id': 'FO681492.1', 'label': 'FO681492.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=FO681492.1'}
# {'id': 'ENSP00000293780', 'label': 'ENSP00000293780', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000293780'}
# {'id': 'ENSG00000283634', 'label': 'MIR3155B', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR3155B'}
# {'id': 'ENSG00000198984', 'label': 'MIR345', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR345'}
# {'id': 'ENSG00000260551', 'label': 'PWRN2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=PWRN2'}
# {'id': 'ENSG00000106133', 'label': 'NSUN5P2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=NSUN5P2'}
# {'id': 'ENSG00000199990', 'label': 'VTRNA1-1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=VTRNA1-1'}
# {'id': 'ENSG00000258057', 'label': 'BCDIN3D-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=BCDIN3D-AS1'}
# {'id': 'ENSG00000186715', 'label': 'MST1L', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MST1L'}
# {'id': 'ENSG00000281828', 'label': 'HERC2P7', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=HERC2P7'}
# {'id': 'AL512631.2', 'label': 'AL512631.2', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AL512631.2'}
# {'id': 'AC124248.1', 'label': 'AC124248.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC124248.1'}
# {'id': 'TNKS2-AS1', 'label': 'TNKS2-AS1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=TNKS2-AS1'}
# {'id': 'ENSG00000258861', 'label': 'MIR381HG', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR381HG'}
# {'id': 'ENSG00000255036', 'label': 'SUGT1P4-STRA6LP-CCDC180', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=SUGT1P4-STRA6LP-CCDC180'}
# {'id': 'ENSG00000276622', 'label': 'MIR6499', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR6499'}
# {'id': 'ENSG00000215417', 'label': 'MIR17HG', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR17HG'}
# {'id': 'ENSG00000232652', 'label': 'LINC02829', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC02829'}
# {'id': 'ENSG00000283609', 'label': 'MIR4662A', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=MIR4662A'}
# {'id': 'ENSG00000233496', 'label': 'SYNJ2-IT1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=SYNJ2-IT1'}
# {'id': 'HSA-MIR-1257', 'label': 'HSA-MIR-1257', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=HSA-MIR-1257'}
# {'id': 'AC124248.1', 'label': 'AC124248.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AC124248.1'}
# {'id': 'ENSG00000232225', 'label': 'LINC01047', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01047'}
# {'id': 'AL136419.1', 'label': 'AL136419.1', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=AL136419.1'}
# {'id': 'ENSG00000280109', 'label': 'PLAC4', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=PLAC4'}
# {'id': 'ENSG00000249346', 'label': 'LINC01016', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=LINC01016'}
# {'id': 'ENSG00000189366', 'label': 'ALG1L', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ALG1L'}
# {'id': 'ENSP00000304169', 'label': 'ENSP00000304169', 'uri': 'https://uswest.ensembl.org/Homo_sapiens/Gene/Summary?g=ENSP00000304169'}

# %%
serialization_v1 = {
    "version": "1",
    "nodes": nodes,
    "edges": edges
}
with open("results/reprotox_serialization.v1.json", "w") as o:
    o.write(json.dumps(serialization_v1, indent=2))

# %%
def isNumber(value):
    try:
        v = int(value)
        return {"@type": "int", "@value": v}
    except:
        try:
            v = float(value)
            return {"@type": "number", "@value": v}
        except:
            return False

# %%
isinstance('', str)
# Out:
# True

# %%
def typer(value):
    numb = isNumber(str(value))
    if numb:
        return numb
    elif isinstance(value, str):
        return {
            "@type": "string",
            "@value": value
        }
    elif isinstance(value, list):
        type_list = []
        for i in value:
            type_list.append(typer(i))
        
        return {
            "@type": "array",
            "@value": type_list
        }
    elif isinstance(value, dict):
        type_dict = {}
        for k,v in value.items():
            if k == "id" or k == "target" or k == "source":
                type_dict[k] = {
                    "@type": "string",
                    "@value": v
                }
            else: type_dict[k] = typer(v)
        return {
            "@type": "object",
            "@value": type_dict
        }

# %%
nodes_v2 = {}
for k,v in nodes.items():
    nodes_v2[k] = typer(v)

# %%
edges_v2 = []
for i in edges:
    edges_v2.append(
        typer(i)
    )

# %%
serialization_v2 = {
    "version": "2",
    "nodes": nodes_v2,
    "edges": edges_v2
}
with open("results/reprotox_serialization.v2.json", "w") as o:
    o.write(json.dumps(serialization_v2, indent=2))

# %%
def get_id(value):
    for prefix, val in rdfgraph.namespaces():
        v = value.replace(val, "")
        if not v == value:
            return prefix, v
    else:
        return "Literal", value

# %% [markdown]
# ## SigCom LINCS
# ### drug2gene

# %%
with open("data/SigComLINCS_drug_2_gene_25.v1.json") as o:
    sigcom_lincs = json.loads(o.read())

# %%
gene_names = set()
for k,v in sigcom_lincs["nodes"].items():
    t = v["type"]
    if t == "Gene":
        gene_names.add(v["properties"]["label"])
len(gene_names)
# Out:
# 4420

# %%
payload = {
    "filter": {
        "where": {
            "meta.symbol": {"inq": list(gene_names)}
        }
    }
}
res = requests.post("https://maayanlab.cloud/sigcom-lincs/metadata-api/entities/find", json=payload)
len(res.json())
# Out:
# 4411

# %%
gene_mapping_name = {
    'LINC00341': 'SYNE3',
    'ATP5MPL': 'ATP5MJ'
}
gene_mapping = {
    'SYNE3': '161176',
    'ATP5MJ': '9556',
    'MIA2': '4253'
}
for i in res.json():
    gene_id = i["meta"]["geneid"]
    gene_symbol = i["meta"]["symbol"]
    if gene_symbol not in gene_mapping:
        gene_mapping[gene_symbol] = gene_id

# %%
for i in gene_names - gene_mapping.keys():
    gene_symbol, gene_id = get_info(i)
    gene_mapping[gene_symbol] = str(gene_id)

# %%
nodes = {}
node_map = {}
ensembl_map = {}
id_mapper = {}
for k,v in sigcom_lincs["nodes"].items():
    t = v["type"]
    v["properties"]["id"] = str(v["properties"]["id"].replace("CID", "CID:"))
    new_v = {}
    for i,j in v["properties"].items():
        new_v[i.replace(".", "_")] = j
    label = new_v["label"]
    if t == "Gene":
        old_id = v["properties"]["id"]
        gene_label = gene_mapping_name.get(label, label)
        gene_id = gene_mapping.get(gene_label)
        if gene_label and gene_id:
            uid = gene_id
            id_mapper[gene_id] = uid
            ensembl_map[old_id] = uid
            new_v["id"] = uid
            new_v["label"] = gene_label
            new_v["uri"] = "https://www.ncbi.nlm.nih.gov/gene/%s"%new_v["id"]
            label = gene_label
            if label in gene_scores.index:
                for key,val in gene_scores.loc[label].items():
                    new_v[key.replace(".", "_")] = val
        else:
            print(label)
            continue
    elif t == "Drug":
        uid = new_v["id"]
        if label in drug_ids:
            uid = drug_ids[label]
        else:
            drug_ids[label] = uid
        id_mapper[new_v["id"]] = uid
        new_v["id"] = uid
        new_v["uri"] = "https://pubchem.ncbi.nlm.nih.gov/compound/%s"%v["properties"]["id"].replace("CID:", "")
        if label in drug_scores.index:
            new_v["placenta_score"] = drug_scores.at[label, "Similarity_Score"]
            new_v["placenta_rank"] = drug_scores.at[label, "Rank"]
    nodes[new_v["id"]] = {
        "type": t,
        "properties": new_v
    }
    node_map[k] = str(v["properties"]["id"])
    node_map[str(new_v["id"])] = str(v["properties"]["id"])
# Out:
# FAM30A

# %%
edges = []
not_in = set()
in_set = set()
for i in sigcom_lincs["edges"]:
    source = id_mapper[str(i["source"].replace("CID", "CID:"))]
    if str(i["target"]) in ensembl_map:
        target = id_mapper[ensembl_map[str(i["target"])]]
        # if source not in node_map: not_in.add(source)
        # else: in_set.add(source)
        # if target not in node_map: not_in.add(target)
        # else: in_set.add(target)
        i["source"] = source
        i["target"] = target
        source_label = nodes[source]["properties"]["label"]
        target_label = nodes[target]["properties"]["label"]
        i["properties"] = {
            "id": "%s %s %s"%(source_label, i["relation"], target_label),
            "source_label": source_label,
            "target_label": target_label,
            "resource": "SigCom LINCS",
            "mean_CD_coefficient": i.pop("weight"),
            "directed": True,
        }
        i["relation"] = "SigCom LINCS Drug-to-Gene (%s)"%i["relation"]
        edges.append(i)

# %%
nodes["CID:9830191"]
# Out:
# {'type': 'Drug',
#  'properties': {'id': 'CID:9830191',
#   'label': 'tipranavir',
#   'uri': 'https://pubchem.ncbi.nlm.nih.gov/compound/9830191'}}

# %%
serialization_v1 = {
    "version": "1",
    "nodes": nodes,
    "edges": edges
}
with open("results/sigcom_lincs_serialization.v1.json", "w") as o:
    o.write(json.dumps(serialization_v1, indent=2))

# %%
nodes_v2 = {}
for k,v in nodes.items():
    nodes_v2[k] = typer(v)

edges_v2 = []
for i in edges:
    edges_v2.append(
        typer(i)
    )
    
serialization_v2 = {
    "version": "2",
    "nodes": nodes_v2,
    "edges": edges_v2
}
with open("results/sigcom_lincs_serialization.v2.json", "w") as o:
    o.write(json.dumps(serialization_v2, indent=2))

# %% [markdown]
# ### Gene 2 Drug (Should I do this?)

# %%
with open("data/full_weights_SigComLINCS_gene_2_drug07262022.v1.json") as o:
    sigcom_lincs = json.loads(o.read())

# %%
nodes = {}
node_map = {}
for k,v in sigcom_lincs["nodes"].items():
    t = v["type"]
    v["properties"]["id"] = str(v["properties"]["id"].replace("CID", "CID:"))
    new_v = {}
    for i,j in v["properties"].items():
        new_v[i.replace(".", "_")] = j
    label = new_v["label"]
    if t == "Gene":
        new_v["id"] = v["properties"]["id"]
        new_v["label"] = v["properties"]["label"]
        new_v["uri"] = "https://www.ncbi.nlm.nih.gov/gene/%s"%new_v["id"]
        if label in gene_scores.index:
            for key,val in gene_scores.loc[label].items():
                new_v[key.replace(".", "_")] = val
    elif t == "Drug":
        new_v["uri"] = "https://pubchem.ncbi.nlm.nih.gov/compound/%s"%v["properties"]["id"].replace("CID:", "")
        if label in drug_scores.index:
            new_v["placenta_score"] = drug_scores.at[label, "Similarity_Score"]
            new_v["placenta_rank"] = drug_scores.at[label, "Rank"]
    nodes[new_v["id"]] = {
        "type": t,
        "properties": new_v
    }
    node_map[k] = str(v["properties"]["id"])
    node_map[str(new_v["id"])] = str(v["properties"]["id"])

# %%
edges = []
not_in = set()
in_set = set()
for i in sigcom_lincs["edges"]:
    source = str(i["source"].replace("CID", "CID:"))
    target = str(i["target"])
    # if source not in node_map: not_in.add(source)
    # else: in_set.add(source)
    # if target not in node_map: not_in.add(target)
    # else: in_set.add(target)
    i["source"] = source
    i["target"] = target
    source_label = nodes[source]["properties"]["label"]
    target_label = nodes[target]["properties"]["label"]
    i["properties"] = {
        "id": "%s %s %s"%(source_label, i["relation"], target_label),
        "source_label": source_label,
        "target_label": target_label,
        "resource": "SigCom LINCS",
        "mean_CD_coefficient": i.pop("weight"),
        "directed": True,
    }
    i["relation"] = "SigCom LINCS (%s)"%i["relation"]
    edges.append(i)

# %%
edges[0]

# %%
payload = {
    "filter": {
        "where": {
            "meta.symbol": {
                "inq": list(not_in)
            }
        }
    }
}

res = requests.post("https://maayanlab.cloud/sigcom-lincs/metadata-api/entities/find", json=payload)
res.ok

# %%
len(not_in), len(res.json())

# %%
not_in - set([i["meta"]["symbol"] for i in res.json()])

# %%
n = set()
for i in res.json():
    if "ensemblid" not in i["meta"]:
        gene_id = str(i["meta"]["geneid"])
        label = i["meta"]["symbol"]
        nodes[gene_id] = {
            "type": "Gene",
            "properties": {
                "id": gene_id,
                "label": label
            }
        }
    else:
        gene_id = str(i["meta"]["ensemblid"])
        label = i["meta"]["symbol"]
        nodes[gene_id] = {
            "type": "Gene",
            "properties": {
                "id": gene_id,
                "label": label
            }
        }
    node_map[label] = gene_id
    node_map[gene_id] = gene_id

# %%
sigcom_lincs["edges"][0]

# %%
edges = []
not_in = {}
in_set = set()
for i in sigcom_lincs["edges"]:
    source = str(i["source"])
    target = str(i["target"])
    
    if source in nodes and target in nodes:
        i["source"] = node_map.get(source, source)
        i["target"] = node_map.get(target, target)
        cd = i["properties"].pop("Mean CD-coefficient", None)
        if cd:
            i["properties"]["mean_CD_coefficient"] = cd
            source_label = nodes[i["source"]]["properties"]["label"]
            target_label = nodes[i["target"]]["properties"]["label"]
            i["properties"]["source_label"] = source_label
            i["properties"]["target_label"] = target_label
            i["properties"]["id"] = "%s_%s_%s"%(source_label, i["relation"], target_label)
            i["relation"] = "SigCom LINCS (%s)"%i["relation"]
        edges.append(i)
    elif not source in nodes:
        if source not in not_in:
            not_in[source] = 0
        not_in[source]+=1
    elif not target in nodes:
        if target not in not_in:
            not_in[target] = 0
        not_in[target]+=1

# %%
edges[1]

# %%
len(edges), len(sigcom_lincs["edges"])

# %%
serialization_v1 = {
    "version": "1",
    "nodes": nodes,
    "edges": edges
}
with open("results/sigcom_lincs_serialization.v1.json", "w") as o:
    o.write(json.dumps(serialization_v1, indent=2))

# %%
nodes_v2 = {}
for k,v in nodes.items():
    nodes_v2[k] = typer(v)

# %%
edges_v2 = []
for i in edges:
    edges_v2.append(
        typer(i)
    )

# %%
nodes_v2 = {}
for k,v in nodes.items():
    nodes_v2[k] = typer(v)

edges_v2 = []
for i in edges:
    edges_v2.append(
        typer(i)
    )
    
serialization_v2 = {
    "version": "2",
    "nodes": nodes_v2,
    "edges": edges_v2
}
with open("results/sigcom_lincs_serialization.v2.json", "w") as o:
    o.write(json.dumps(serialization_v2, indent=2))

# %% [markdown]
# ### Drug2Drug

# %%
with open("data/full_SigComLINCS_lm_drug_cosine_sim.v1.json") as o:
    drug2drug = json.loads(o.read())

# %%
nodes = {}
id_mapper = {}
for k,v in drug2drug["nodes"].items():
    properties = v["properties"]
    properties["id"] = k.replace("CID", "CID:")
    if k == "CID4549":
        print(properties["id"])
    label = properties["label"]
    uid = properties["id"]
    if label in drug_ids:
        id_mapper[uid] = drug_ids[label]
        uid = drug_ids[label]
    else:
        id_mapper[uid] = uid
        drug_ids[label] = uid
    properties["id"] = uid

    id_mapper[properties["id"]] = uid
    properties["uri"] = "https://pubchem.ncbi.nlm.nih.gov/compound/%s"%v["properties"]["id"].replace("CID:", "")
    if label in drug_scores.index:
        properties["placenta_score"] = drug_scores.at[label, "Similarity_Score"]
        properties["placenta_rank"] = drug_scores.at[label, "Rank"]
    nodes[properties["id"]] = {
        "type": v["type"],
        "properties": properties
    }
# Out:
# CID:4549

# %%
edges = []
for i in drug2drug["edges"]:
    source = id_mapper[i["source"].replace("CID", "CID:")]
    source_label = nodes[source]["properties"]["label"]
    target = id_mapper[i["target"].replace("CID", "CID:")]
    target_label = nodes[target]["properties"]["label"]
    relation = "LINCS Drugs Cosine Similarity"
    cosine_similarity = i["weight"]

    edges.append({
        "source": source,
        "relation": relation,
        "target": target,
        "properties": {
            "id": "%s-%s similarity"%(source_label, target_label),
            "source_label": source_label,
            "target_label": target_label,
            "cosine_similarity": cosine_similarity
        }
    })

# %%
serialization_v1["edges"][0]
# Out:
# {'source': 'CID:9830191',
#  'relation': 'SigCom LINCS Drug-to-Gene (upregulates)',
#  'target': '347',
#  'properties': {'id': 'tipranavir upregulates APOD',
#   'source_label': 'tipranavir',
#   'target_label': 'APOD',
#   'resource': 'SigCom LINCS',
#   'mean_CD_coefficient': 0.0037570596,
#   'directed': True}}

# %%
serialization_v1 = {
    "version": "1",
    "nodes": nodes,
    "edges": edges
}
with open("results/sigcom_lincs_drug_similarity.v1.json", "w") as o:
    o.write(json.dumps(serialization_v1, indent=2))

# %%
nodes_v2 = {}
for k,v in nodes.items():
    nodes_v2[k] = typer(v)

edges_v2 = []
for i in edges:
    edges_v2.append(
        typer(i)
    )

serialization_v2 = {
    "version": "2",
    "nodes": nodes_v2,
    "edges": edges_v2
}
with open("results/sigcom_lincs_drug_similarity.v2.json", "w") as o:
    o.write(json.dumps(serialization_v2, indent=2))

# %% [markdown]
# ## Drug Target

# %%
drug_target = pd.read_csv("data/idg_target.tsv", sep="\t")
drug_target.head()
# Out:
#                                          DRUG_SMILES      DRUG_NAME  DRUG_ID  \
# 0  CCN(CC)CCNC(=O)C1=C(C)NC(\C=C2/C(=O)NC3=C2C=C(...      sunitinib     2544
# 1  CN(C)C[C@@H]1CCN2C=C(C3=CC=CC=C23)C2=C(C(=O)NC...  ruboxistaurin     3533
# 2     N#CC[C@H](C1CCCC1)N1C=C(C=N1)C1=C2C=CNC2=NC=N1    ruxolitinib     4190
# 3  COC(=O)C1=CC2=C(C=C1)\C(=C(\NC1=CC=C(C=C1)N(C)...     nintedanib     4903
# 4  CCS(=O)(=O)N1CC(CC#N)(C1)N1C=C(C=N1)C1=NC=NC2=...    baricitinib     5202
#
#    DRUG_PUBCHEM_CID                      TARGET_NAME TARGET_CLASS TARGET_GENE  \
# 0           5329102  AP2-associated protein kinase 1       Kinase        AAK1
# 1            153999  AP2-associated protein kinase 1       Kinase        AAK1
# 2          25126798  AP2-associated protein kinase 1       Kinase        AAK1
# 3         135423438  AP2-associated protein kinase 1       Kinase        AAK1
# 4          44205240  AP2-associated protein kinase 1       Kinase        AAK1
#
#   TARGET_ACCESSION TARGET_SWISSPROT TARGET_ORGANISM TARGET_TDL ACT_TYPE  \
# 0           Q2M2I8       AAK1_HUMAN    Homo sapiens      Tchem       Kd
# 1           Q2M2I8       AAK1_HUMAN    Homo sapiens      Tchem       Kd
# 2           Q2M2I8       AAK1_HUMAN    Homo sapiens      Tchem       Kd
# 3           Q2M2I8       AAK1_HUMAN    Homo sapiens      Tchem       Kd
# 4           Q2M2I8       AAK1_HUMAN    Homo sapiens      Tchem       Kd
#
#   ACT_RELATION  ACT_VALUE                                        ACT_COMMENT  \
# 0            =       7.96            Binding constant for AAK1 kinase domain
# 1            =       6.05            Binding constant for AAK1 kinase domain
# 2            =       6.92            Binding constant for AAK1 kinase domain
# 3            =       7.20            Binding constant for AAK1 kinase domain
# 4            =       7.77  Binding affinity determined in a cell-free bio...
#
#   ACT_SOURCE
# 0     CHEMBL
# 1     CHEMBL
# 2     CHEMBL
# 3     CHEMBL
# 4     IUPHAR

# %%
nodes = {}
edges = []

# %%
drug_ids["terconazole"]
# Out:
# 'CID:441383'

# %%
for drug_id in set(drug_target["DRUG_ID"]):
    sub_df = drug_target[drug_target["DRUG_ID"] == drug_id]
    for i in sub_df.index:
        drug_pubchem_id = "CID:%s"%sub_df.at[i, "DRUG_PUBCHEM_CID"]
        drug_name = sub_df.at[i, "DRUG_NAME"]
        if drug_name in drug_ids:
            drug_pubchem_id = drug_ids[drug_name]
        else:
            drug_ids[drug_name] = drug_pubchem_id
        if drug_pubchem_id not in nodes:
            properties = {
                "id": drug_pubchem_id,
                "label": drug_name,
                "smiles": sub_df.at[i, "DRUG_SMILES"],
                "IDG_ID": str(sub_df.at[i, "DRUG_ID"]),
                "uri": "https://pubchem.ncbi.nlm.nih.gov/compound/%s"%str(sub_df.at[i, "DRUG_PUBCHEM_CID"])
            }
            if drug_name in drug_scores.index:
                properties["placenta_score"] = float(drug_scores.at[drug_name, "Similarity_Score"])
                properties["placenta_rank"] = int(drug_scores.at[drug_name, "Rank"])
            nodes[drug_pubchem_id] = {
                "type": "Drug",
                "properties": properties
            }
        
        gene_label = sub_df.at[i, "TARGET_GENE"]
        gene_label, gene_id = get_info(gene_label)
        if gene_label and gene_id:
            if gene_id not in nodes:
                properties = {
                    "id": gene_id,
                    "label": gene_label,
                    "target_name": str(sub_df.at[i, "TARGET_NAME"]),
                    "target_class": str(sub_df.at[i, "TARGET_CLASS"]),
                    "accession": str(sub_df.at[i, "TARGET_ACCESSION"]),
                    "swissprot": str(sub_df.at[i, "TARGET_SWISSPROT"]),
                    "organism": str(sub_df.at[i, "TARGET_ORGANISM"]),
                    "TDL": str(sub_df.at[i, "TARGET_TDL"])
                }
                if gene_label in gene_scores.index:
                    for k,v in gene_scores.loc[gene_label].items():
                        properties[k.replace(".", "_")] = float(v)
                nodes[gene_id] = {
                    "type": "Gene",
                    "properties": properties
                }
            edge = {
                "source": drug_pubchem_id,
                "relation": "IDG (Drug Target)",
                "target": gene_id,
                "properties": {
                    "id": "%s targets %s"%(drug_name, gene_label),
                    "source_label": drug_name,
                    "target_label": gene_label,
                    "act_type": str(sub_df.at[i, "ACT_TYPE"]),
                    "act_relation": str(sub_df.at[i, "ACT_RELATION"]),
                    "act_value": str(sub_df.at[i, "ACT_VALUE"]),
                    "act_comment": str(sub_df.at[i, "ACT_COMMENT"]),
                    "act_source": str(sub_df.at[i, "ACT_SOURCE"]),
                }
            }
            edges.append(edge)
        else:
            print(sub_df.at[i, "TARGET_GENE"])

# %%
nodes[drug_ids["terconazole"]]
# Out:
# {'type': 'Drug',
#  'properties': {'id': 'CID:441383',
#   'label': 'terconazole',
#   'smiles': 'CC(C)N1CCN(CC1)C1=CC=C(OCC2COC(CN3C=NC=N3)(O2)C2=CC=C(Cl)C=C2Cl)C=C1',
#   'IDG_ID': '2599',
#   'uri': 'https://pubchem.ncbi.nlm.nih.gov/compound/5404',
#   'placenta_score': 0.005863704,
#   'placenta_rank': 14339}}

# %%
serialization_v1 = {
    "version": "1",
    "nodes": nodes,
    "edges": edges
}
with open("results/idg_drug_targets.v1.json", "w") as o:
    o.write(json.dumps(serialization_v1, indent=2))

# %%
nodes_v2 = {}
for k,v in nodes.items():
    nodes_v2[k] = typer(v)

edges_v2 = []
for i in edges:
    edges_v2.append(
        typer(i)
    )

serialization_v2 = {
    "version": "2",
    "nodes": nodes_v2,
    "edges": edges_v2
}
with open("results/idg_drug_targets.v2.json", "w") as o:
    o.write(json.dumps(serialization_v2, indent=2))

# %% [markdown]
# ### HPO

# %%
HPO_Freq.head()
# Out:
#                                    HPO description  KF Frequency
# HPO ID
# HP:0410030                               Cleft lip           888
# HP:0000776         Congenital diaphragmatic hernia           770
# HP:0000175                            Cleft palate           704
# HP:0010438  Abnormal ventricular septum morphology           629
# HP:0001710                      Conotruncal defect           545

# %%
nodes = {}
edges = []
for i in HPO_Freq.index:
    if i not in nodes:
        label = HPO_Freq.at[i, "HPO description"]
        if type(label) == pd.core.series.Series:
            label = label[0]
        KF_Freq =  HPO_Freq.at[i, "KF Frequency"]
        if type(KF_Freq) == pd.core.series.Series:
            KF_Freq = int(KF_Freq[0])
        else:
            KF_Freq = int(KF_Freq)
        nodes[i] = {
            "type": "BirthDefect",
            "properties": {
                "id": i,
                "label": label,
                "KF_Freq": KF_Freq,
                "uri": "https://purl.obolibrary.org/obo/%s"%i.replace(":", "_")
            }
        }
        time.sleep(0.1)
        res = requests.get("https://hpo.jax.org/api/hpo/term/%s/genes?max=-1&offset=1"%i, verify=False)
        if not res.ok:
            print(i)
        else:
            for gene_info in res.json()["genes"]:
                entrezGeneId = str(gene_info["entrezGeneId"])
                entrezGeneSymbol = gene_info["entrezGeneSymbol"]
                gene_label, gene_id = get_info(entrezGeneSymbol)
                if entrezGeneSymbol == 'KCNQ1OT1':
                    print(gene_label)
                if gene_label and gene_id not in nodes:
                    properties = {
                        "id": gene_id,
                        "label": gene_label,
                        "uri": "https://www.ncbi.nlm.nih.gov/gene/%s"%gene_id
                    }
                    if gene_label in gene_scores:
                        for k,v in gene_scores.loc[gene_label]:
                            properties[k.replace(".", "_" )] = v
                    
                    nodes[gene_id] = {
                        "type": "Gene",
                        "properties": properties
                    }
                    edge = {
                        "source": i,
                        "relation": "HPO",
                        "target": gene_id,
                        "properties": {
                            "id": "%s (%s-%s)"%(i, label, gene_label),
                            "source_label": label,
                            "target_label": gene_label,
                            "resource": "HPO"
                        }
                    }
                    edges.append(edge)
# Out:
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# None
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/maayanlab/Documents/codebase/KnowledgExchange/reprotox-kg/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hpo.jax.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
serialization_v1 = {
    "version": "1",
    "nodes": nodes,
    "edges": edges
}
with open("results/hpo.v1.json", "w") as o:
    o.write(json.dumps(serialization_v1, indent=2))

# %%
nodes_v2 = {}
for k,v in nodes.items():
    nodes_v2[k] = typer(v)

edges_v2 = []
for i in edges:
    edges_v2.append(
        typer(i)
    )

serialization_v2 = {
    "version": "2",
    "nodes": nodes_v2,
    "edges": edges_v2
}
with open("results/hpo.v2.json", "w") as o:
    o.write(json.dumps(serialization_v2, indent=2))

# %%
with open("data/drug_ids.json", "w") as o:
    o.write(json.dumps(drug_ids, indent=2))

with open("data/birth_defect_ids.json", "w") as o:
    o.write(json.dumps(birth_defect_ids, indent=2))

# %%
duplicates = {}
for i in glob.glob("results/*.v1.json"):
    with open(i) as o:
        serialization = json.loads(o.read())
        for k,v in serialization["nodes"].items():
            uid = v["properties"]["id"]
            label = v["type"] + "_" + v["properties"]["label"]
            if label in duplicates and not duplicates[label] == uid:
                print(label, uid, duplicates[label], i)
            else:
                duplicates[label] = uid
# Out:
# Gene_ND1 6775098 4535 results/hpo.v1.json

# %%
get_info('ND1')
# Out:
# ('ND1', '6775098')

# %%
with open("results/reprotox_serialization.v1.json") as o:
    s = json.loads(o.read())

[i for i in s["nodes"].values() if i["properties"]["label"] == "MIA2"]
# Out:
# []

# %%
get_info('MIA2')

# %%
drug_ids["68740"]

# %% [markdown]
# ### ARCHS4

# %%
import pyarrow.feather as feather
from scipy.stats import rankdata, zscore

# %%
human_correlation = feather.read_feather('data/human_correlation_archs4.f')

# %%
human_correlation.index = human_correlation.columns
human_correlation.head()

# %%
human_correlation_rank = pd.DataFrame(0, columns=human_correlation.columns, index=human_correlation.columns)

# %%
import numpy as np

mat = np.zeros(shape=(len(human_correlation.columns), len(human_correlation.columns)))

# %%
index = 0
for col in tqdm(human_correlation.columns):
    mat[index] = rankdata(human_correlation[col], method="ordinal")
    index += 1

human_correlation_rank = pd.DataFrame(mat.T, columns=human_correlation.columns, index=human_correlation.columns)

# %%
human_correlation_rank.head()

# %%
organism='Mammalia/Homo_sapiens'
ncbi = fetch_save_read(
    'ftp://ftp.ncbi.nih.gov/gene/DATA/GENE_INFO/{}.gene_info.gz'.format(organism),
    '{}.gene_info.tsv'.format(organism),
    sep='\t',
)
ncbi = ncbi.set_index("GeneID")

# %%
ncbi.head()

# %%
nodes = {} 
edges = {}
no_data = set()
gene_types = {}
for gene in tqdm(human_correlation_rank.index):
    # check if we want this gene
    gene_symbol, gene_id = get_info(gene)
    if gene_symbol and gene_id:
        if gene_id not in nodes:
            synonyms = list(set(ncbi.at[int(gene_id), "Synonyms"].split("|")))
            XRefs = {}
            gene_type = ncbi.at[int(gene_id), "type_of_gene"]
            if gene_type not in gene_types:
                gene_types[gene_type] = 0
            gene_types[gene_type] += 1
            for i in ncbi.at[int(gene_id), "dbXrefs"].split("|"):
                split = i.split(":")
                k = split[0]
                v = ":".join(split[1:])
                XRefs[k] = v
            scores = {}
            if gene_symbol in gene_scores.index:
                for k,v in gene_scores.loc[gene_symbol].items():
                    scores[k.replace(".", "_")] = v
            
            nodes[gene_id] = {
                "type": "Gene",
                "properties": {
                    "id": gene_id,
                    "label": gene_symbol,
                    "uri": "https://www.ncbi.nlm.nih.gov/gene/%s"%gene_id,
                    **scores
                }
            }
#             if len(synonyms):
#                 nodes[gene_id]["properties"]["synonyms"] = synonyms
#             if len(XRefs):
#                 nodes[gene_id]["properties"]["XRefs"] = ["%s: %s"%(k,v) for k,v in XRefs.items()]
        rank = 0
        count = 0
        sorted_genes = human_correlation_rank[gene].sort_values().index
        while count < 5:
            coexpressed_gene = sorted_genes[rank]
            coexpressed_symbol, coexpressed_id = get_info(coexpressed_gene)
            if coexpressed_symbol and coexpressed_id:
                if coexpressed_id not in nodes:
                    gene_type = ncbi.at[int(coexpressed_id), "type_of_gene"]
                    if gene_type not in gene_types:
                        gene_types[gene_type] = 0
                    gene_types[gene_type] += 1
                    synonyms = list(set(ncbi.at[int(coexpressed_id), "Synonyms"].split("|")))
                    XRefs = {}
                    for i in ncbi.at[int(coexpressed_id), "dbXrefs"].split("|"):
                        split = i.split(":")
                        k = split[0]
                        v = ":".join(split[1:])
                        XRefs[k] = v
                    scores = {}
                    if coexpressed_symbol in gene_scores.index:
                        for k,v in gene_scores.loc[coexpressed_symbol].items():
                            scores[k.replace(".", "_")] = v
                    nodes[coexpressed_id] = {
                        "type": "Gene",
                        "properties": {
                            "id": coexpressed_id,
                            "label": coexpressed_symbol,
                            "uri": "https://www.ncbi.nlm.nih.gov/gene/%s"%coexpressed_id,
                            **scores
                        }
                    }
#                     if len(synonyms):
#                         nodes[coexpressed_id]["properties"]["synonyms"] = synonyms
#                     if len(XRefs):
#                         nodes[coexpressed_id]["properties"]["XRefs"] = ["%s: %s"%(k,v) for k,v in XRefs.items()]
                    
                edge_1 = (gene_id, coexpressed_id)
                edge_2 = (coexpressed_id, gene_id)
                if edge_1 not in edges and edge_2 not in edges:
                    edges[edge_1] = {
                        "type": "Relation",
                        "source": gene_id,
                        "relation": "ARCHS4 (negatively correlated)",
                        "target": coexpressed_id,
                        "properties": {
                            "resource": "ARCHS4",
                            "source_label": gene_symbol,
                            "target_label": coexpressed_symbol,
                            "label": "negatively correlated",
                            "id": "%s is negatively correlated with %s"%(gene_symbol, coexpressed_symbol),
                            "correlation_coefficient": human_correlation.at[coexpressed_gene, gene]
                        }
                    }
                count += 1
            rank += 1
            
        count = 0
        rank = len(sorted_genes) - 1
        
        while count < 5:
            coexpressed_gene = sorted_genes[rank]
            if not gene == coexpressed_gene:
                coexpressed_symbol, coexpressed_id = get_info(coexpressed_gene)
                if coexpressed_symbol and coexpressed_id:
                    if coexpressed_id not in nodes:
                        nodes[coexpressed_id] = {
                            "type": "Gene",
                            "properties": {
                                "id": coexpressed_id,
                                "label": coexpressed_symbol
                            }
                        }
                    edge_1 = (gene_id, coexpressed_id)
                    edge_2 = (coexpressed_id, gene_id)
                    if edge_1 not in edges and edge_2 not in edges:
                        edges[edge_1] = {
                            "type": "Relation",
                            "source": gene_id,
                            "relation": "ARCHS4 (positively correlated)",
                            "target": coexpressed_id,
                            "properties": {
                                "resource": "ARCHS4",
                                "source_label": gene_symbol,
                                "target_label": coexpressed_symbol,
                                "label": "positively correlated",
                                "id": "%s is positively correlated with %s"%(gene_symbol, coexpressed_symbol),
                                "correlation_coefficient": human_correlation.at[coexpressed_gene, gene]
                            }
                        }
                    count += 1
            rank -= 1
    else:
        no_data.add(gene)
print(len(no_data))

# %%
gene_types

# %%
len(nodes), len(edges)

# %%
serialization_v1 = {
    "version": "1",
    "nodes": nodes,
    "edges": list(edges.values())
}
with open("results/archs4_coexpression.v1.json", "w") as o:
    o.write(json.dumps(serialization_v1, indent=2))

nodes_v2 = {}
for k,v in tqdm(nodes.items()):
    nodes_v2[k] = typer(v)
edges_v2 = []
for i in tqdm(edges.values()):
    edges_v2.append(
        typer(i)
    )

serialization_v2 = {
    "version": "2",
    "nodes": nodes_v2,
    "edges": edges_v2
}
with open("results/archs4_coexpression.v2.json", "w") as o:
    o.write(json.dumps(serialization_v2, indent=2))

# %% [markdown]
# ### copy

# %%
for i in glob.glob('results/*.v1.json'):
    with open(i) as o:
        new_file = i.replace("v1", "valid").replace('results', 'ingestion')
        with open(new_file, 'w') as w:
            w.write(o.read())

# %%
for i in glob.glob('results/*.v1.json'):
    with open(i) as o:
        serialization = json.loads(o.read())
        print("file: %s, nodes: %s, edges: %s"%(i, len(serialization["nodes"]),len(serialization["edges"])))
